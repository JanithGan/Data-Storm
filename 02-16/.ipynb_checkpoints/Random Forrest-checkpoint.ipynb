# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
from imblearn.over_sampling import SMOTENC

from xgboost import XGBClassifier
from sklearn.ensemble import *
from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import *

# %% [markdown]
# ## Import Data

# %%
# Reading Processed Train Set Data File
raw_d1 = pd.read_csv('Data/Processed_Trainset.csv')

# Feature Headers List
headers = list(raw_d1.columns)

# Reading Test Data Set
raw_d2 = pd.read_csv('Data/Processed_Testset.csv')

id_col = list(raw_d2.Client_ID)
raw_d2.drop(['Client_ID'], axis=1, inplace=True)

# %% [markdown]
# ## Correlation

# %%
# Generating Heat Map
correlation = raw_d1.corr()
correlation.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_b957683e_50b5_11ea_a25c_dd7d20644d37row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row0_col1 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row0_col2 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row0_col3 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row0_col4 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row0_col5 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row0_col6 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row0_col7 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row0_col8 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row0_col9 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row0_col10 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row0_col11 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row0_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row0_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row0_col14 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row0_col15 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row0_col16 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row0_col17 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row0_col18 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row0_col19 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row1_col0 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row1_col3 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row1_col4 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row1_col5 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row1_col6 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row1_col7 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row1_col8 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row1_col9 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row1_col10 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row1_col11 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row1_col12 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row1_col13 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row1_col14 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row1_col15 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row1_col16 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row1_col17 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row1_col18 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row1_col19 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row2_col0 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row2_col3 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row2_col4 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row2_col5 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row2_col6 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row2_col7 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row2_col8 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row2_col9 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row2_col10 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row2_col11 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row2_col12 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row2_col13 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row2_col14 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row2_col15 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row2_col16 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row2_col17 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row2_col18 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_b957683e_50b5_11ea_a25c_dd7d20644d37row2_col19 {
#             background-color:  #5673e0;

# %% [markdown]
# ## Formatting

# %%
# Convert Data into ndArrays
train_data = np.array(raw_d1)
test_data = np.array(raw_d2)

# Total Training Data
X_tot = train_data[:, :-1]
Y_tot = train_data[:, -1]

# Splitting Data into a Training Set and a Cross Validation Set
X_train, X_cross, Y_train, Y_cross = train_test_split(X_tot, Y_tot, test_size = 0.15, random_state = 42, shuffle = True)
X_train.shape, Y_train.shape
# Out:
# ((20400, 19), (20400,))

# %% [markdown]
# ## SMOTE

# %%
# smote = SMOTENC(list(range(0,18)), sampling_strategy='auto', k_neighbors=10, n_jobs=1)
# X_train,Y_train = smote.fit_resample(X_train, Y_train)

# pd.DataFrame(np.concatenate((X_train,np.reshape(Y_train, (Y_train.shape[0], 1))), axis=1)
#              ,columns=headers).to_csv('Data/SMOTED.csv', index=None)
# X_train.shape, Y_train.shape

# %% [markdown]
# ## Normalizing Data

# %%
# sc = RobustScaler()
# sc.fit(X_tot)

# X_tot = sc.fit_transform(X_tot)
# X_train = sc.transform(X_train)
# X_cross = sc.transform(X_cross)
# test_data = sc.transform(test_data)

# pd.DataFrame(X_tot, columns=headers[:-1])

# %% [markdown]
# ## Classification Model

# %%
# rf = GradientBoostingClassifier(n_estimators= 300)

rf = RandomForestClassifier(bootstrap=True, class_weight= None, max_depth= 8, max_features= 10, max_leaf_nodes= None,
                            min_samples_leaf= 1, min_samples_split= 2, min_weight_fraction_leaf= 0.0, n_estimators= 500,
                            n_jobs= 1, oob_score= False, random_state= 85, verbose= 0, warm_start= False)
# rf = XGBClassifier()

rf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=8, max_features=10,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#                        oob_score=False, random_state=85, verbose=0,
#                        warm_start=False)

# %% [markdown]
# ## Prediction and Evaluation

# %%
# Predicting Outcomes
predict_train = rf.predict(X_train)
predict_cross = rf.predict(X_cross)
predict_tot = rf.predict(X_tot)
predict_test = rf.predict(test_data)

# Computing Confusion Matrix on Cross Validation Set
confusion = confusion_matrix(Y_cross,predict_cross)

# Computing Accuracy Values
accuracy_train = accuracy_score(Y_train, predict_train)
accuracy_cross = accuracy_score(Y_cross, predict_cross)
accuracy_tot = accuracy_score(Y_tot, predict_tot)

# Computing AUC Values
auc_train = roc_auc_score(Y_train, predict_train)
auc_cross = roc_auc_score(Y_cross, predict_cross)
auc_tot = roc_auc_score(Y_tot, predict_tot)                

# Printing Accuracy Metrics
print("Train Accuracy            : {:.3f}%       AUC: {:.4f}".format(accuracy_train * 100, auc_train))
print("Cross Validation Accuracy : {:.3f}%       AUC: {:.4f} ".format(accuracy_cross * 100, auc_cross))
print("Total Set Accuracy        : {:.3f}%       AUC: {:.4f}".format(accuracy_tot * 100, auc_tot))
print("Confusion Matrix for Cross Validation Set :\n %s" % str(confusion))
print("Number of Ones Predicted for Test Data : %d" % np.sum(predict_test))

print(classification_report(Y_cross, predict_cross))
# Out:
# Train Accuracy            : 83.431%       AUC: 0.6769
# Cross Validation Accuracy : 83.250%       AUC: 0.6647
# Total Set Accuracy        : 83.404%       AUC: 0.6752
# Confusion Matrix for Cross Validation Set :
#  [[2710  114]
#  [ 489  287]]
# Number of Ones Predicted for Test Data : 664
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.96      0.90      2824
#          1.0       0.72      0.37      0.49       776
#
#     accuracy                           0.83      3600
#    macro avg       0.78      0.66      0.69      3600
# weighted avg       0.82      0.83      0.81      3600

# %% [markdown]
# ## Upload

# %%
# Uploading Predictions to a CSV
df = pd.DataFrame(predict_test, dtype=int)
df.index = id_col
df.to_csv('Data/Submission.csv', header=['NEXT_MONTH_DEFAULT'], index_label='Client_ID')
